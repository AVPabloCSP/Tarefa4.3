# %% [markdown]
# # Proba de Jupyter
# Este é un exemplo creado dende cero para a tarefa 4.3 Jupyter.

# %%
print("Hola mundo dende Jypyter!")
# Out:
# Hola mundo dende Jypyter!

# %% [markdown]
# ## Estruturas básicas en Python
#
# Imos mostrar unha lista e iterar por ela.

# %%
frutas = ["mazá", "pera", "plátano", "kiwi"]

for f in frutas:
    print("Froita:", f)
# Out:
# Froita: mazá
# Froita: pera
# Froita: plátano
# Froita: kiwi
